# %% [markdown]
# <a href="https://colab.research.google.com/github/mnocerino23/Into-the-Wild/blob/main/Overnights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2021-2022 ITW Trips Year in Review

# %% [markdown]
# ![ITW Logo.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Read in dataset containing information and sign up data for all of Into the Wild's overnight camping/backpacking trips during the 2021-2022 school year at Santa Clara University.

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
overnight_trips = pd.read_csv('/content/drive/MyDrive/Data_Science_Projects/Into_the_Wild/Into the Wild Trip Results 2021 - Overnights.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
print(overnight_trips.columns)
# Out:
# Index(['Year', 'Trip Name', 'Trip Type', 'Skill Level', 'Terrain Type',
#        'Region', 'County', 'Swimming?', 'Application?', 'Price', 'Quarter',
#        'Week in the quarter', 'Long Weekend', 'Two overnights',
#        'Number of ITW trips', 'Number of Nights', 'Day Leave', 'Day Return',
#        'Distance (miles)', 'New trip?', 'Tickets Sold', 'Trip',
#        'Tickets Available', 'Empty spots', 'Filled?'],
#       dtype='object')

# %%
#Add in feature that represents the  

overnight_trips = overnight_trips.assign(PercentSold=lambda x: (x['Tickets Sold'] / x['Tickets Available']))

# %%
overnight_trips.head(5)
# Out:
#    Year                     Trip Name    Trip Type   Skill Level Terrain Type  \
# 0  2021                    Sword Lake  Backpacking      Beginner     Mountain
# 1  2021             Big Sur (Vicente)  Backpacking  Intermediate        Coast
# 2  2021           Emigrant Wilderness  Backpacking      Advanced     Mountain
# 3  2021  Redwoods/Manresa State Beach        Beach      Beginner        Beach
# 4  2021        Big Sur (Salmon Creek)  Backpacking      Beginner        Coast
#
#           Region      County  Swimming?  Application?  Price  ... Day Leave  \
# 0        Sierras   Tuolumne           1             0   40.0  ...  Saturday
# 1  Central Coast    Monterey          0             0   40.0  ...  Saturday
# 2        Sierras    Tuolumne          0             0   50.0  ...  Saturday
# 3          Local  Santa Cruz          1             0   32.0  ...  Saturday
# 4  Central Coast    Monterey          0             0   25.0  ...  Saturday
#
# ...

# %%
overnight_trips.describe()
# Out:
#               Year  Swimming?  Application?     Price  Week in the quarter  \
# count    26.000000  26.000000     26.000000  25.00000            26.000000
# mean   2021.730769   0.384615      0.115385  44.04000             5.384615
# std       0.452344   0.496139      0.325813  21.10387             2.562451
# min    2021.000000   0.000000      0.000000   0.00000             1.000000
# 25%    2021.250000   0.000000      0.000000  30.00000             4.000000
# 50%    2022.000000   0.000000      0.000000  40.00000             6.000000
# 75%    2022.000000   1.000000      0.000000  50.00000             7.000000
# max    2022.000000   1.000000      1.000000  80.00000             9.000000
#
#        Long Weekend  Two overnights  Number of ITW trips  Number of Nights  \
# count     26.000000       26.000000            26.000000         26.000000
# mean       0.192308        0.307692             2.653846          1.153846
# ...

# %% [markdown]
# # Recap of Into the Wild 2021 Trips - Trip Type, Skill Level, and Terrain

# %%
sns.histplot(data=overnight_trips, x="Trip Type", color = "orange")
plt.title('2021-2022 Overnight Trip Types', fontsize=14)
# Out:
# Text(0.5, 1.0, '2021-2022 Overnight Trip Types')

# %%
overnight_trips['Trip Type'].value_counts()
# Out:
# Car Camping    12
# Backpacking    11
# Beach           3
# Name: Trip Type, dtype: int64

# %%
sns.histplot(data = overnight_trips, x = "Skill Level", color = "blue")
plt.title('2021-2022 Overnight Trip Levels', fontsize=14)
# Out:
# Text(0.5, 1.0, '2021-2022 Overnight Trip Levels')

# %%
overnight_trips['Skill Level'].value_counts()
# Out:
# Beginner        14
# Intermediate     8
# Advanced         4
# Name: Skill Level, dtype: int64

# %%
sns.histplot(data = overnight_trips, x = "Terrain Type", color = "magenta")
plt.title('2021-2022 Overnight Trip Terrain', fontsize=14)
# Out:
# Text(0.5, 1.0, '2021-2022 Overnight Trip Terrain')

# %%
overnight_trips['Terrain Type'].value_counts()
# Out:
# Coast       10
# Mountain     8
# Beach        5
# Desert       3
# Name: Terrain Type, dtype: int64

# %%
sns.histplot(data = overnight_trips, x = "Day Leave")
plt.title('2021-2022 Overnight Trips Day of Departure', fontsize=14)
# Out:
# Text(0.5, 1.0, '2021-2022 Overnight Trips Day of Departure')

# %%
overnight_trips['Day Leave'].value_counts()
# Out:
# Saturday    21
# Friday       5
# Name: Day Leave, dtype: int64

# %%
sns.histplot(data = overnight_trips, x = "Number of Nights", color = 'yellow', bins = 2)
plt.title('2021-2022 Overnight Trips Day of Departure', fontsize=14)
# Out:
# Text(0.5, 1.0, '2021-2022 Overnight Trips Day of Departure')

# %%
sns.histplot(data = overnight_trips, x = "Quarter", color = "brown")
plt.title('2021-2022 Overnight Trips by Quarter', fontsize=14)
# Out:
# Text(0.5, 1.0, '2021-2022 Overnight Trips by Quarter')

# %% [markdown]
# # Where we got Wild:

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(data = overnight_trips, x = "Region",  bins = 20)
plt.title('2021-2022 Overnight Trips by Region', fontsize=25)
# Out:
# Text(0.5, 1.0, '2021-2022 Overnight Trips by Region')

# %%
overnight_trips['Region'].value_counts()
# Out:
# Sierras                7
# Central Coast          7
# Local                  5
# North                  3
# Marin                  2
# Southern California    1
# East Sierras           1
# Name: Region, dtype: int64

# %%
sns.histplot(data = overnight_trips, x = "County",  bins = 20)
plt.title('2021-2022 Overnight Trips by County', fontsize=25)
# Out:
# Text(0.5, 1.0, '2021-2022 Overnight Trips by County')

# %%
overnight_trips['County'].value_counts()
# Out:
# Monterey         7
# Santa Cruz       4
# Tuolumne         3
# Mariposa         3
# Marin            2
# Sonoma           2
# Tuolumne         1
# San Benito       1
# San Bernadino    1
# Inyo             1
# Shasta           1
# Name: County, dtype: int64

# %% [markdown]
# # Trip Distances

# %%
sns.histplot(data = overnight_trips, x = "Distance (miles)", bins = 5, kde = True, color = 'Green')
plt.title('Driving Distances of 2021-2022 ITW Overnights', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Driving Distances of 2021-2022 ITW Overnights')

# %% [markdown]
# Violin Plot using Seaborn:

# %%
plt.title('Distribution of Distances of 2021-2022 ITW Overnights', fontsize=20)
sns.set_theme(style="whitegrid")
ax = sns.violinplot(x=overnight_trips["Distance (miles)"])

# %% [markdown]
# # Pricing of 2021-2022 Overnights

# %%
sns.histplot(data = overnight_trips, x = "Price", bins = 10, kde = True, color = 'Purple', hue = 'Number of Nights')
plt.title('Histogram of 2021-2022 ITW Overnight Prices', fontsize=20)
plt.xlabel('Trip Price (USD)')
# Out:
# Text(0.5, 0, 'Trip Price (USD)')

# %% [markdown]
# Violin Plot using seaborn:

# %%
plt.title('Price Distribution of 2021-2022 ITW Overnights', fontsize=20)
sns.set_theme(style="whitegrid")
ax = sns.violinplot(x=overnight_trips["Price"])

# %%
sns.histplot(data = overnight_trips, x = "PercentSold", bins = 5, kde = True)
plt.title('Percent Full 2021-2022 Overnights', fontsize=20)
plt.xlabel('Trip Price (USD)')
# Out:
# Text(0.5, 0, 'Trip Price (USD)')

# %% [markdown]
# # Investigating the lack of sign ups during the 2021-2022 school year

# %% [markdown]
# Introduce a new feature titled 'Success'. If 85% of a trip's available tickets sell, we consider the trip a success. If the number is less, we consider the trip not succesfully filled. This will be a better metric than the 'Filled?' feature we currently have since it allows for trips with very few empty spots to be still considered succesful (how the org views them).

# %%
overnight_trips['Success'] = overnight_trips['PercentSold'].apply(lambda x: 1 if x >= 0.85 else 0)

# %%
overnight_trips.head(25)
# Out:
#     Year                           Trip Name    Trip Type   Skill Level  \
# 0   2021                          Sword Lake  Backpacking      Beginner
# 1   2021                   Big Sur (Vicente)  Backpacking  Intermediate
# 2   2021                 Emigrant Wilderness  Backpacking      Advanced
# 3   2021        Redwoods/Manresa State Beach        Beach      Beginner
# 4   2021              Big Sur (Salmon Creek)  Backpacking      Beginner
# 5   2021                           Pinnacles  Car Camping      Beginner
# 6   2021                 Big Sur (Cone Peak)  Car Camping      Advanced
# 7   2022                     Yosemite Winter  Car Camping      Beginner
# 8   2022                         Joshua Tree  Car Camping      Beginner
# 9   2022               Point Reyes (Wildcat)  Backpacking  Intermediate
# 10  2022                  Sunset State Beach        Beach      Beginner
# 11  2022                Salt Point Overnight  Car Camping      Beginner
# ...

# %%
#correct for one missing value that was causing issues below
#had to go back into our pre trip form to find the price of the point reyes overnight
overnight_trips.at[22, "Price"] = 47.0

# %%
overnight_trips.to_csv('Overnights.csv', index = False)

# %%
#Use seaborn heatmap to visualize the correlation between trip sign up and other features
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.subplots(figsize = (26,26))
sns.heatmap(overnight_trips.corr(), 
            vmin = -1,
            vmax = 1, 
            center = 0,
            cmap = sns.diverging_palette(20,220,n = 200),
            annot = True, annot_kws = {'size': 15},
            square = True
            )

# %% [markdown]
# Figure out the most important features in determining whether a trip is succesful (with a sign up rate of over 90%)

# %%
overnight_trips.head(5)
# Out:
#    Year                     Trip Name    Trip Type   Skill Level Terrain Type  \
# 0  2021                    Sword Lake  Backpacking      Beginner     Mountain
# 1  2021             Big Sur (Vicente)  Backpacking  Intermediate        Coast
# 2  2021           Emigrant Wilderness  Backpacking      Advanced     Mountain
# 3  2021  Redwoods/Manresa State Beach        Beach      Beginner        Beach
# 4  2021        Big Sur (Salmon Creek)  Backpacking      Beginner        Coast
#
#           Region      County  Swimming?  Application?  Price  ... Day Return  \
# 0        Sierras   Tuolumne           1             0   40.0  ...     Sunday
# 1  Central Coast    Monterey          0             0   40.0  ...     Sunday
# 2        Sierras    Tuolumne          0             0   50.0  ...     Sunday
# 3          Local  Santa Cruz          1             0   32.0  ...     Sunday
# 4  Central Coast    Monterey          0             0   25.0  ...     Sunday
#
# ...

# %% [markdown]
# One-hot encode Trip Type, Skill Level, Terrain Type, Day Leave

# %%
dummy_triptype = pd.get_dummies(overnight_trips['Trip Type'])
dummy_skill = pd.get_dummies(overnight_trips['Skill Level'])
dummy_terrain = pd.get_dummies(overnight_trips['Terrain Type'])
dummy_dayleave = pd.get_dummies(overnight_trips['Day Leave'])
dummy_quarter = pd.get_dummies(overnight_trips['Quarter'])

one_hot_encoded = [dummy_triptype, dummy_skill, dummy_terrain, dummy_dayleave, dummy_quarter]
for features in one_hot_encoded:
  overnight_trips = pd.merge(left = overnight_trips, right = features, left_index = True, right_index = True)

overnight_trips = overnight_trips.drop(columns = ['Trip Type', 'Skill Level', 'Terrain Type', 'Day Leave'])
overnight_trips.head(5)
# Out:
#    Year                     Trip Name         Region      County  Swimming?  \
# 0  2021                    Sword Lake        Sierras   Tuolumne           1
# 1  2021             Big Sur (Vicente)  Central Coast    Monterey          0
# 2  2021           Emigrant Wilderness        Sierras    Tuolumne          0
# 3  2021  Redwoods/Manresa State Beach          Local  Santa Cruz          1
# 4  2021        Big Sur (Salmon Creek)  Central Coast    Monterey          0
#
#    Application?  Price Quarter  Week in the quarter  Long Weekend  ...  \
# 0             0   40.0    Fall                    1             0  ...
# 1             0   40.0    Fall                    2             0  ...
# 2             0   50.0    Fall                    4             0  ...
# 3             0   32.0    Fall                    5             0  ...
# 4             0   25.0    Fall                    6             0  ...
#
#    Intermediate  Beach_y  Coast Desert  Mountain  Friday  Saturday Fall  \
# ...

# %%
overnight_trips.to_csv('Overnights_encoded.csv', index = False)

# %% [markdown]
# We don't have large enough of a dataset to build classifiers or regression models for trip sign ups, but we can still use sklearn's selectkbest method to find the most import features

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# %%
overnight_trips.columns
# Out:
# Index(['Year', 'Trip Name', 'Region', 'County', 'Swimming?', 'Application?',
#        'Price', 'Quarter', 'Week in the quarter', 'Long Weekend',
#        'Two overnights', 'Number of ITW trips', 'Number of Nights',
#        'Day Return', 'Distance (miles)', 'New trip?', 'Tickets Sold', 'Trip',
#        'Tickets Available', 'Empty spots', 'Filled?', 'PercentSold', 'Success',
#        'Backpacking', 'Beach_x', 'Car Camping', 'Advanced', 'Beginner',
#        'Intermediate', 'Beach_y', 'Coast', 'Desert', 'Mountain', 'Friday',
#        'Saturday', 'Fall', 'Spring', 'Winter'],
#       dtype='object')

# %%
features = overnight_trips.drop(['Year', 'Trip Name', 'Region', 'County', 'Day Return', 'Tickets Sold', 'Trip', 'Quarter', 'Tickets Available',
                                 'Empty spots', 'Filled?', 'PercentSold', 'Success'], axis = 1)
target = overnight_trips['Success']

# %%
top_features_ordered = []

# %%
for i in range(len(features)-1):
  best_features = SelectKBest(f_classif, k=i)
  k_best_data = best_features.fit_transform(features, target)
  mask = best_features.get_support()
  new_features = features.columns[mask]
  for item in new_features:
    if item not in top_features_ordered:
      top_features_ordered.append(item)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_selection/_base.py:99: UserWarning: No features were selected: either the data is too noisy or the selection test too strict.
#   UserWarning,

# %%
count = 0
for feature in top_features_ordered:
  count +=1
  print(count, ': ', feature)
# Out:
# 1 :  Week in the quarter
# 2 :  Car Camping
# 3 :  Application?
# 4 :  Spring
# 5 :  Fall
# 6 :  Beach_x
# 7 :  Number of Nights
# 8 :  Advanced
# 9 :  Mountain
# 10 :  Two overnights
# 11 :  Price
# 12 :  Backpacking
# 13 :  Beach_y
# 14 :  Distance (miles)
# 15 :  Long Weekend
# 16 :  Beginner
# 17 :  Desert
# 18 :  Winter
# 19 :  Intermediate
# 20 :  Coast
# 21 :  Swimming?
# 22 :  New trip?
# 23 :  Friday
# 24 :  Saturday

# %% [markdown]
# Below, I will explore some common opinions held by club members and investigate the validty of each of these by looking at the dataset

# %% [markdown]
# Are car camping trips more popular than backpacking trips? Or vice versa? Or both equal popularity

# %% [markdown]
# # Notion #1: Trips later in the quarter have more difficulty filling up

# %% [markdown]
# # Notion #2: Into the Wild Trips are popular in the fall and less so in winter and spring

# %% [markdown]
# # Notion #3: Two Night Long Weekend Trips have lost popularity

# %% [markdown]
# # Notion #4: High Trip Cost May Prevent Sign ups

# %% [markdown]
# # Notion #5: There is a lack of demand for advanced trips right now

# %% [markdown]
# # Question: Do locations lose popularity when we provide many opportunities to go there? Look at Point Reyes, Yosemite, and Big Sur.
